# %% [markdown]
# # 02 Train GAN
#
# Notebook wrapper around `train_gan.py`. Adjust the parameter cell, then run the training cell when you are ready.

# %%
from pathlib import Path
from dataclasses import replace
import json
import os
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
scripts_dir = ROOT / "scripts"
if str(scripts_dir) not in sys.path:
    sys.path.insert(0, str(scripts_dir))
os.chdir(ROOT)

from config import Config
from train_gan import train

ROOT

# %%
# Edit these values before running.
DATA_ROOT = ROOT / "data_final"
FID_ROOT = ROOT / "data_final"
OUT_DIR = ROOT / "runs" / "gan"

# Example for a smaller debug run:
# cfg = replace(Config(), gan_epochs=20, fid_every=5, sample_every=5, ckpt_every=10)
cfg = Config()

print(DATA_ROOT)
print(FID_ROOT)
print(OUT_DIR)
cfg

# %%
gan_run = train(cfg, data_root=DATA_ROOT, fid_root=FID_ROOT, out_dir=OUT_DIR)
gan_run["summary"]

# %%
summary_path = OUT_DIR / "run_summary.json"
if summary_path.exists():
    summary = json.loads(summary_path.read_text())
    summary
else:
    print("No run summary yet. Train the GAN first.")
